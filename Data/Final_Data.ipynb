# %% [markdown]
#  ## Enhance Data
#  We Enhance the existing dataset by adding three critical columns: skills, tools, and job title, to better align with the needs of the chat application 'اجادة'.
#
#  Column Addition
# Using ChatGPT for advanced data extraction, three new columns were added:

# %%
import pandas as pd

# %%
df_1 = pd.read_csv("./C_Skills.csv")
df_2 = pd.read_csv("./TQ_Skills.csv")

# %%
df_1.head()
# Out:
#    Unnamed: 0                       Course_Name  \
# 0           0         مقدمة في المشاريع التقنية
# 1           1             تعلم الآلة (ML) - 101
# 2           2   تحليل البيانات الاستكشافي (EDA)
# 3           3     تمثيل البيانات: مكتبة Seaborn
# 4           4  تمثيل البيانات: مكتبة Matplotlib
#
#                                   Course_Description  \
# 0  سنتعرف في هذة الدورة على ماهية المشاريع التقني...
# 1  يهدف الدورة للتعرف على مفهوم تعلم الآلة (Machi...
# 2  تهدف الدورة للتعرف على خطوات تحليل البيانات ال...
# 3  تهدف الدورة للتعرف على ما هي مكتبة Seaborn، وم...
# 4  تهدف الدورة للتعرف على كيفية تمثيل البيانات با...
#
#                                       learning_goals  level duration  \
# 0  ماهو المشروع وصفاته وأمثلة للمشاريع التقنية, م...  مبتدئ   ساعتان
# 1  أنواع خوارزميات تعلم الآلة., مراحل بناء نماذج ...  متوسط   ساعتان
# 2  التحليل الوصفي (Descriptive Analysis), تحليل م...  متوسط   ساعتان
# 3  التعرف على مكتبة Seaborn., التعرف على أنواع ال...  مبتدئ   ساعتان
# ...

# %%
df_2.head()
# Out:
#                                         Course Name Type_of_Program  \
# 0                         فعالية WWDC24 Watch Party            لقاء
# 1                إدارة خدمات تقنية المعلومات (ITIL)          برنامج
# 2        الذكاء الاصطناعي التوليدي القائم على LLAMA           معسكر
# 3             التطوير باستخدام تقنيات الواقع الممتد           معسكر
# 4  برمجة لغة C# لبناء عوالم افتراضية باستخدام Unity           معسكر
#
#                                          Description  \
# 0  فعالية مصاحبة تقام على جانب مؤتمر شركة Apple ا...
# 1  برنامج تدريبي يستهدف المهتمين بتعلم مفاهيـم 4 ...
# 2  يهدف البرنامج التدريبي إلى التعرف على الذكاء ا...
# 3  معسكر تطوير تقنيات الواقع الممتد هو برنامج تعل...
# 4  ستتعلم من خلال هذا المعسكر البرمجة بلغة C# كما...
#
#                                                Goals Location  Date Range  \
# 0                                          غير مذكور   الرياض    يوم واحد
# 1  , تعزيز وزيادة المعرفة والإلمام بالمعلومات الأ...   الرياض  أسبوع واحد
# ...
